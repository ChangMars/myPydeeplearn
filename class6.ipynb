# %%
from sklearn.datasets import load_boston
import pandas as pd
boston = load_boston()
df = pd.DataFrame(boston["data"], columns=boston["feature_names"])
df["target"] = boston["target"]
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(boston["data"],
                                                  boston["target"],
                                                  test_size=0.1)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=5)
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
import graphviz
from sklearn.tree import export_graphviz
g = export_graphviz(reg, out_file=None,
                   feature_names=boston["feature_names"],
                   filled = True)
graphviz.Source(g)

# %%
print("預測結果:", list(reg.predict(x_test)))
print("正確結果:", list(y_test))

from sklearn.metrics import r2_score
print("r2 score:", r2_score(y_test, reg.predict(x_test)))
# Out:
# 預測結果: [20.494545454545452, 22.923287671232874, 17.137209302325584, 14.350000000000001, 27.099999999999998, 22.923287671232874, 22.923287671232874, 13.253846153846155, 20.494545454545452, 22.923287671232874, 13.9, 13.253846153846155, 9.00344827586207, 22.923287671232874, 27.099999999999998, 20.494545454545452, 22.923287671232874, 20.494545454545452, 42.7, 20.494545454545452, 20.494545454545452, 20.494545454545452, 17.137209302325584, 20.494545454545452, 20.494545454545452, 20.494545454545452, 14.350000000000001, 22.923287671232874, 23.066666666666663, 27.099999999999998, 22.923287671232874, 14.350000000000001, 33.064444444444455, 42.7, 22.923287671232874, 20.494545454545452, 20.494545454545452, 13.9, 9.00344827586207, 22.923287671232874, 9.00344827586207, 22.923287671232874, 33.064444444444455, 27.099999999999998, 20.494545454545452, 20.494545454545452, 27.099999999999998, 22.923287671232874, 33.064444444444455, 20.494545454545452, 13.9]
# 正確結果: [19.3, 18.2, 21.5, 19.3, 23.9, 18.9, 22.5, 14.6, 23.0, 18.6, 11.9, 14.9, 11.5, 36.2, 25.1, 19.5, 24.3, 24.0, 43.5, 26.4, 27.5, 17.5, 27.1, 22.0, 18.6, 16.2, 19.4, 20.6, 21.7, 16.5, 25.0, 15.6, 34.7, 50.0, 22.1, 22.2, 19.1, 13.8, 8.4, 22.9, 12.1, 22.0, 29.9, 28.4, 21.4, 25.0, 24.4, 26.4, 26.7, 19.2, 13.3]
# r2 score: 0.6956605804666249
