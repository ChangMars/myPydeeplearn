# %%
from sklearn.datasets import load_boston
import pandas as pd
boston = load_boston()
df = pd.DataFrame(boston["data"], columns=boston["feature_names"])
df["target"] = boston["target"]
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
# [90%題目,10%題目, 90%答案, 10%答案]
x_train, x_test, y_train, y_test= train_test_split(boston["data"],
                                                  boston["target"],
                                                  test_size=0.1)

# %%
# 做公式
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=5)
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
import graphviz
from sklearn.tree import export_graphviz
g = export_graphviz(reg, out_file=None,
                   feature_names=boston["feature_names"],
                   filled = True)
graphviz.Source(g)

# %%
print("預測結果:", list(reg.predict(x_test)))
print("正確結果:", list(y_test))

from sklearn.metrics import r2_score
print("r2 score:", r2_score(y_test, reg.predict(x_test)))
# Out:
# 預測結果: [50.0, 34.55454545454546, 40.7, 21.498295454545442, 30.225, 14.093750000000002, 34.55454545454546, 17.525000000000002, 34.55454545454546, 17.525000000000002, 21.498295454545442, 21.498295454545442, 21.498295454545442, 21.498295454545442, 40.7, 9.957142857142859, 50.0, 29.140000000000004, 17.525000000000002, 21.498295454545442, 21.498295454545442, 25.908571428571435, 21.498295454545442, 21.498295454545442, 17.525000000000002, 14.093750000000002, 21.498295454545442, 25.908571428571435, 34.55454545454546, 17.525000000000002, 21.498295454545442, 9.957142857142859, 14.093750000000002, 49.82857142857143, 44.5, 16.19, 21.498295454545442, 50.0, 30.225, 17.525000000000002, 46.275000000000006, 46.275000000000006, 29.140000000000004, 30.156249999999996, 34.55454545454546, 17.525000000000002, 23.25, 17.525000000000002, 34.55454545454546, 17.525000000000002, 21.498295454545442]
# 正確結果: [36.5, 26.6, 50.0, 20.0, 20.3, 20.0, 29.6, 12.7, 33.0, 12.5, 20.5, 21.4, 18.5, 19.0, 21.9, 7.2, 36.0, 31.6, 16.7, 21.4, 21.6, 29.0, 20.6, 19.1, 13.1, 19.3, 18.2, 32.0, 37.2, 17.5, 25.0, 10.8, 8.1, 50.0, 42.3, 10.2, 22.7, 27.9, 22.0, 13.3, 43.8, 46.7, 25.0, 31.6, 29.0, 17.4, 19.4, 13.6, 33.2, 14.9, 22.9]
# r2 score: 0.6355659230827353
